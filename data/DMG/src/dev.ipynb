# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()
import numpy as np

# %%
df = pd.read_csv("../dumps/API_dump_public_2026-02-18_extracted.csv")

# %%
df.groupby("object_number")

# %%
def compact(series, keep_repetitions=False, as_string=True, sep="&semi;"):
    u = series.unique()
    if len(u) == 0:
        return "" if as_string else None
    elif len(u) == 1:
        return series.iloc[0]
    else:
        x = series if keep_repetitions else u
        return sep.join(x) if as_string else list(x)


# def implode(df, on="object_number", as_string=True, sep="&semi;"):
def _implode(subdf):
    return [compact(subdf[col].dropna(), as_string=as_string, sep=sep) for col in subdf.columns]# + [subdf.name]
on="object_number"
as_string=True
sep="&semi;"

small = df.iloc[:10]
rows = small.groupby(on).progress_apply(_implode)
x = pd.DataFrame(rows.tolist(), index=rows.index).reset_index()
x.columns = df.columns

# implode(df.iloc[:10])




# df.columns
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 138.61it/s]

# %%
from .data.data import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from .data.data import *
#
# ImportError: attempted relative import with no known parent package

# %%
pd.DataFrame(rows.tolist()).reset_index
# Out:
# <bound method DataFrame.reset_index of                                                   0   \
# 0  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 1  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 2  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 3  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 4  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 5  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 6  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 7  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 8  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 9  https://stad.gent/id/mensgemaaktobject/dmg/530...
#
#                                     1   \
# 0       Halvemaanbuffet in empirestijl
# 1  Stoel met opengewerkte rug met band
# 2      Massieve wastafel met palmetten
# 3               Uitschuifbare eettafel
# 4        Lage tafel met gekrulde poten
# 5               Stoel in Sheratonstijl
# 6  Wandspiegel met geprofileerde lijst
# 7        Voetenbank in Louis XVI-stijl
# 8     Vierdeurskast in Louis XVI-stijl
# 9        Haardscherm met bloemenmeisje
#
#                                                   2   \
# 0  Kenmerkend voor de empirestijl waarin dit halv...
# 1  De opengewerkte schildvorm van de holle rugleu...
# 2  Deze wastafel of wastafel-commode heeft een ui...
# 3  Deze ovalen tafel kan worden uitgeschoven om d...
# 4  Deze lage tafel rust op aan het uiteinde naar ...
# 5  Deze stoel werd in de Sheratonstijl gemaakt. T...
# 6  Kleine houten wandspiegel met een geprofileerd...
# 7  Kenmerkend voor de classicistische of Louis XV...
# 8  Deze vierdeurskast bestaat uit een onder- en e...
# 9  Dit haardscherm in classicistische of Louis XV...
#
#                                      3                     4   \
# 0  http://vocab.getty.edu/aat/300172119                buffet
# 1  http://vocab.getty.edu/aat/300037772                 stoel
# 2  http://vocab.getty.edu/aat/300039857     wastafel (meubel)
# 3  http://vocab.getty.edu/aat/300039648              eettafel
# 4  http://vocab.getty.edu/aat/300039998           bijzettafel
# 5  http://vocab.getty.edu/aat/300037772                 stoel
# 6  http://vocab.getty.edu/aat/300223968           wandspiegel
# 7  http://vocab.getty.edu/aat/300038435            voetenbank
# 8  http://vocab.getty.edu/aat/300038860  bergmeubel&semi;kast
# 9  http://vocab.getty.edu/aat/300262203           haardscherm
#
#                                                   5   \
# 0  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 1  https://stad.gent/id/mensgemaaktobject/dmg/530...
# 2             https://stad.gent/id/concept/530010570
# 3             https://stad.gent/id/concept/530010570
# 4             https://stad.gent/id/concept/530010570
# 5             https://stad.gent/id/concept/530010570
# 6
# 7             https://stad.gent/id/concept/530010570
# 8             https://stad.gent/id/concept/530010570
# 9             https://stad.gent/id/concept/530010570
#
#                                                   6   \
# 0  https://www.projectcest.be/wiki/Publicatie:Inv...
# 1  https://www.projectcest.be/wiki/Publicatie:Inv...
# 2  https://www.projectcest.be/wiki/Publicatie:Inv...
# 3  https://www.projectcest.be/wiki/Publicatie:Inv...
# 4  https://www.projectcest.be/wiki/Publicatie:Inv...
# 5  https://www.projectcest.be/wiki/Publicatie:Inv...
# 6
# 7  https://www.projectcest.be/wiki/Publicatie:Inv...
# 8  https://www.projectcest.be/wiki/Publicatie:Inv...
# 9  https://www.projectcest.be/wiki/Publicatie:Inv...
#
#                                                   7   \
# 0  https://apidg.gent.be/opendata/adlib2eventstre...
# 1  https://apidg.gent.be/opendata/adlib2eventstre...
# 2  https://apidg.gent.be/opendata/adlib2eventstre...
# 3  https://apidg.gent.be/opendata/adlib2eventstre...
# 4  https://apidg.gent.be/opendata/adlib2eventstre...
# 5  https://apidg.gent.be/opendata/adlib2eventstre...
# 6
# 7  https://apidg.gent.be/opendata/adlib2eventstre...
# 8  https://apidg.gent.be/opendata/adlib2eventstre...
# 9  https://apidg.gent.be/opendata/adlib2eventstre...
#
#                                      8                               9   ...  \
# 0                                                                        ...
# 1                                                                        ...
# 2                                                                        ...
# 3                                                                        ...
# 4  http://vocab.getty.edu/aat/300012424  rozenhout&semi;palissanderhout  ...
# 5                                                                        ...
# 6                                                                        ...
# 7                                                                        ...
# 8  http://vocab.getty.edu/aat/300011914                            hout  ...
# 9                                                                        ...
#
#          17 18 19  20                                  21          22  \
# 0                  ..  http://vocab.getty.edu/tgn/7018236  Vlaanderen
# 1                  ..  http://vocab.getty.edu/tgn/7002445    Engeland
# 2                  ..
# 3                  ..  http://vocab.getty.edu/tgn/7002445    Engeland
# 4                  ..  http://vocab.getty.edu/tgn/1000111       China
# 5                  ..  http://vocab.getty.edu/tgn/7002445    Engeland
# 6  onbekend
# 7                  ..
# 8                  ..  http://vocab.getty.edu/tgn/7018236  Vlaanderen
# 9                  ..  http://vocab.getty.edu/tgn/1000070   Frankrijk
#
#                                      23        24    25    26
# 0  https://stad.gent/id/agent/530000494  onbekend        True
# 1  https://stad.gent/id/agent/530000494  onbekend        True
# 2  https://stad.gent/id/agent/530000494  onbekend  1947  True
# 3  https://stad.gent/id/agent/530000494  onbekend        True
# 4  https://stad.gent/id/agent/530000494  onbekend  1960  True
# 5  https://stad.gent/id/agent/530000494  onbekend  1913  True
# 6                                                        True
# 7  https://stad.gent/id/agent/530000494  onbekend  1907  True
# 8  https://stad.gent/id/agent/530000494  onbekend        True
# 9  https://stad.gent/id/agent/530000494  onbekend  1913  True
#
# [10 rows x 27 columns]>

# %% [markdown]
# ---
# ## do array chunks have indexes?

# %%
def _get_texts(r):
    return f"{r.title}\n{r.description}".strip()

t = df.fillna("").apply(_get_texts, axis=1)

# %%
todo = np.array_split(t, int(len(t)/512))

# %%
class T:
    def __new__(self):
        return None

T() is None
# Out:
# True
